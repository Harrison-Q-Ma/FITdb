# %%
import cellbrowser.cellbrowser as cb
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad('../scanpy_obj/Haag_2024_adata_processed_harmony.h5ad')
cb.scanpyToCellbrowser(adata, "../cellbrowser_Haag_2024", "Haag_2024", skipMatrix = False, coordFields = ['X_umap']) 
cb.build("../cellbrowser_Haag_2024", "../cellbrowser_Haag_2024/cellbrowser_Haag_2024_html")
